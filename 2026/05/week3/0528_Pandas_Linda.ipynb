# %% [markdown]
# *   NumPy는 수학 계산에 초점
# *   Pandas는 데이터를 구조적으로 관리하고 분석하는 데 특화

# %% [markdown]
# #시리즈 교재

# %% [markdown]
# #시리즈 미니퀘스트

# %% [markdown]
# ###1번 퀘스트
# Pandas의 Series를 리스트 [5, 10, 15, 20]을 사용하여 생성하고, Series의 인덱스를 확인하는 코드를 작성하세요.

# %%
import pandas as pd

#""리스트"" 기본 생성
series = pd.Series([5,10,15,20])
print(series, '\n')

#인덱스 변경
series.index=['a', 'b', 'c', 'd']
print(series, '\n')

#모든 요소에 2 곱하기
print(series*2)
# Out:
# 0     5
# 1    10
# 2    15
# 3    20
# dtype: int64
#
# a     5
# b    10
# c    15
# d    20
# dtype: int64
#
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 다음 딕셔너리를 이용하여 Pandas Series를 생성하고, 인덱스를 활용하여 'b'의 값을 출력하는 코드를 작성하세요.
#
# ```python
# data = {'a': 100, 'b': 200, 'c': 300}
# ```
#
# </aside>

# %%
# ""딕셔너리"" 기본 생성
data = {'a': 100, 'b': 200, 'c': 300}
series = pd.Series(data)

print(series, '\n')
#인덱스 b의 값 출력
print(series['b'])
# Out:
# a    100
# b    200
# c    300
# dtype: int64
#
# 200

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 다음 Pandas Series에 대해 결측값(`NaN`)을 확인하고, 모든 결측값을 `0`으로 채운 후 Series의 값을 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# series = pd.Series([1, 2, None, 4, None, 6])
# ```
#
# </aside>

# %%
series = pd.Series([1, 2, None, 4, None, 6])

#기본 none을 0으로 변경 후 출력
print(series.fillna(0), '\n')

#데이터타입을 int로 변경
a = series.fillna(0)
print(a.astype('int'))
# Out:
# 0    1.0
# 1    2.0
# 2    0.0
# 3    4.0
# 4    0.0
# 5    6.0
# dtype: float64
#
# 0    1
# 1    2
# 2    0
# 3    4
# 4    0
# 5    6
# dtype: int64

# %% [markdown]
# # 데이터 프레임 교재

# %% [markdown]
# # 데이터프레임 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 다음 데이터프레임에서 열(column)의 이름들을 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희'],
#         '나이': [25, 30, 28],
#         '성별': ['남', '남', '여']}
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {'이름': ['홍길동', '김철수', '박영희'],
        '나이': [25, 30, 28],
        '성별': ['남', '남', '여']}
df = pd.DataFrame(data)

print(df['이름'])
# Out:
# 0    홍길동
# 1    김철수
# 2    박영희
# Name: 이름, dtype: object

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 다음 데이터프레임에서 나이 열(age)을 기준으로 오름차순으로 정렬된 새로운 데이터프레임을 생성하고 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희'],
#         '나이': [25, 30, 28],
#         '성별': ['남', '남', '여']}
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
new_df = df.sort_values(by='나이')
print(df)
# Out:
#     이름  나이 성별
# 0  홍길동  25  남
# 1  김철수  30  남
# 2  박영희  28  여

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 아래와 같은 데이터프레임이 있습니다.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희', '이순신'],
#         '국어': [85, 90, 88, 92],
#         '영어': [78, 85, 89, 87],
#         '수학': [92, 88, 84, 90]}
# df = pd.DataFrame(data)
# ```
#
# 각 학생의 총점을 계산하는 새로운 열을 추가한 후, 총점이 250점 이상인 학생들만 포함된 데이터프레임을 생성하세요.
#
# </aside>

# %%
data = {'이름': ['홍길동', '김철수', '박영희', '이순신'],
        '국어': [85, 90, 88, 92],
        '영어': [78, 85, 89, 87],
        '수학': [92, 88, 84, 70]}     # <-- 문제에서 주어진 조건이면 모두 만족하길래 마지막 데이터에 변형을 줌.
df = pd.DataFrame(data)

#새로운 열 '총점' 추가
df['총점'] = df['국어'] + df['영어'] + df['수학']

#비교를 위해 전체 데이터 출력
print(f"전체 데이터 출력: \n{df}")

#조건에 만족하는 데이터만 출력
print("\n조건을 만족하는 데이터만 출력:\n", df[df['총점'] >= 250])
# Out:
# 전체 데이터 출력:
#     이름  국어  영어  수학   총점
# 0  홍길동  85  78  92  255
# 1  김철수  90  85  88  263
# 2  박영희  88  89  84  261
# 3  이순신  92  87  70  249
#
# 조건을 만족하는 데이터만 출력:
#      이름  국어  영어  수학   총점
# 0  홍길동  85  78  92  255
# 1  김철수  90  85  88  263
# 2  박영희  88  89  84  261

# %% [markdown]
# # 필터링 교재

# %% [markdown]
# # 필터링 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 나이가 30 이상인 행만 필터링하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬'],
#         '나이': [25, 30, 35, 40, 45],
#         '도시': ['서울', '부산', '서울', '대구', '부산']}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {'이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬'],
        '나이': [25, 30, 35, 40, 45],
        '도시': ['서울', '부산', '서울', '대구', '부산']}

df = pd.DataFrame(data)

print(df[df['나이'] >= 30])
# Out:
#     이름  나이  도시
# 1  김철수  30  부산
# 2  박영희  35  서울
# 3  이순신  40  대구
# 4  강감찬  45  부산

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 도시가 '서울'이거나 점수가 80점 이상인 데이터를 필터링하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬'],
#         '나이': [25, 30, 35, 40, 45],
#         '도시': ['서울', '부산', '서울', '대구', '부산'],
#         '점수': [85, 90, 75, 95, 80]}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
df['점수'] = [85, 70, 75, 95, 80]     # <-- 필터링 확인을 위해 데이터 변경

print( df[  (df['도시'] == '서울') | (df['점수'] >= 80)  ] )
# Out:
#     이름  나이  도시  점수
# 0  홍길동  25  서울  85
# 2  박영희  35  서울  75
# 3  이순신  40  대구  95
# 4  강감찬  45  부산  80

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 **`query()`**를 사용하여 나이가 35 이상이고 점수가 80점 초과인 데이터를 필터링하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {'이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬'],
#         '나이': [25, 30, 35, 40, 45],
#         '도시': ['서울', '부산', '서울', '대구', '부산'],
#         '점수': [85, 90, 75, 95, 80]}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
print(f"현재 데이터 상태: \n{df}")

print(f"\n query를 이용한 조건 출력:\n {df.query('나이 >= 35 & 점수 > 80')}")
# Out:
# 현재 데이터 상태:
#     이름  나이  도시  점수
# 0  홍길동  25  서울  85
# 1  김철수  30  부산  70
# 2  박영희  35  서울  75
# 3  이순신  40  대구  95
# 4  강감찬  45  부산  80
#
#  query를 이용한 조건 출력:
#      이름  나이  도시  점수
# 3  이순신  40  대구  95

# %% [markdown]
# # 그룹화 교재

# %% [markdown]
# # 그룹화 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 `groupby()`를 사용하여 '부서'별로 급여의 합계를 구하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '이름': ['홍길동', '김철수', '박영희', '이순신'],
#     '부서': ['영업', '영업', '인사', '인사'],
#     '급여': [5000, 5500, 4800, 5100]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '이름': ['홍길동', '김철수', '박영희', '이순신'],
    '부서': ['영업', '영업', '인사', '인사'],
    '급여': [5000, 5500, 4800, 5100]
}

df = pd.DataFrame(data)

print(df.groupby('부서').groups, '\n')
print(df.groupby('부서').groups.keys(), '\n')
print(df.groupby('부서')['급여'].mean())
# Out:
# {'영업': [0, 1], '인사': [2, 3]}
#
# dict_keys(['영업', '인사'])
#
# 부서
# 영업    5250.0
# 인사    4950.0
# Name: 급여, dtype: float64

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 아래 데이터프레임에서 `groupby()`와 `agg()`를 사용하여 '부서'별 급여의 합계(`sum`)와 평균(`mean`)을 계산하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬', '신사임당'],
#     '부서': ['영업', '영업', '인사', '인사', 'IT', 'IT'],
#     '급여': [5000, 5500, 4800, 5100, 6000, 6200]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
df.loc[5] = ['강감찬', 'IT', 6000]
df.loc[6] = ['신사임당', 'IT', 6200]

#데이터 추가 후 정상 출력되는지 확인
print(df, '\n\n')
#과제 실행
df.groupby('부서')['급여'].agg(['sum', 'mean'])
# Out:
#      이름  부서    급여
# 0   홍길동  영업  5000
# 1   김철수  영업  5500
# 2   박영희  인사  4800
# 3   이순신  인사  5100
# 5   강감찬  IT  6000
# 6  신사임당  IT  6200
#       sum    mean
# 부서
# IT  12200  6100.0
# 영업  10500  5250.0
# 인사   9900  4950.0

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 부서별로 데이터를 그룹화한 뒤, 각 부서의 평균 급여가 5000 이상인 경우만 필터링하는 코드를 작성하시오.
#
# ```python
# import pandas as pd
#
# data = {
#     '이름': ['홍길동', '김철수', '박영희', '이순신', '강감찬', '신사임당'],
#     '부서': ['영업', '영업', '인사', '인사', 'IT', 'IT'],
#     '급여': [5000, 5500, 4800, 5100, 6000, 6200]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
print(df.groupby('부서').filter(lambda x : x['급여'].mean() >= 5000))
# Out:
#      이름  부서    급여
# 0   홍길동  영업  5000
# 1   김철수  영업  5500
# 5   강감찬  IT  6000
# 6  신사임당  IT  6200

# %% [markdown]
# # 병합 교재

# %% [markdown]
# # 병합 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 두 개의 데이터프레임을 `고객ID`를 기준으로 내부 조인(`inner join`)하여 공통된 데이터를 병합하는 코드를 작성하세요.
#
# ```
# import pandas as pd
#
# df1 = pd.DataFrame({'고객ID': [1, 2, 3], '이름': ['홍길동', '김철수', '이영희']})
# df2 = pd.DataFrame({'고객ID': [2, 3, 4], '구매액': [10000, 20000, 30000]})
# ```
#
# </aside>

# %%
df1 = pd.DataFrame({'고객ID': [1, 2, 3], '이름': ['홍길동', '김철수', '이영희']})
df2 = pd.DataFrame({'고객ID': [2, 3, 4], '구매액': [10000, 20000, 30000]})

new_df = pd.merge(df1, df2, how='inner')
print(new_df, '\n\n')

print(pd.merge(df1, df2, how='outer'))
# Out:
#    고객ID   이름    구매액
# 0     2  김철수  10000
# 1     3  이영희  20000
#
#
#    고객ID   이름      구매액
# 0     1  홍길동      NaN
# 1     2  김철수  10000.0
# 2     3  이영희  20000.0
# 3     4  NaN  30000.0

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 왼쪽 데이터프레임을 기준으로 병합(`left join`)을 수행하고, 구매액이 없는 경우 `NaN`을 유지하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# df1 = pd.DataFrame({'고객ID': [1, 2, 3], '이름': ['홍길동', '김철수', '이영희']})
# df2 = pd.DataFrame({'고객ID': [2, 3, 4], '구매액': [15000, 25000, 35000]})
# ```
#
# </aside>

# %%
print(pd.merge(df1, df2, how='left'))
# Out:
#    고객ID   이름      구매액
# 0     1  홍길동      NaN
# 1     2  김철수  10000.0
# 2     3  이영희  20000.0

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 두 개 이상의 열을 기준으로 병합하고, 중복 열의 이름을 구분하도록 접미사(`suffixes`)를 지정하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# df1 = pd.DataFrame({
#     '고객ID': [1, 2, 3],
#     '도시': ['서울', '부산', '대전'],
#     '구매액': [10000, 20000, 30000]
# })
#
# df2 = pd.DataFrame({
#     '고객ID': [1, 2, 3],
#     '도시': ['서울', '부산', '광주'],
#     '구매액': [15000, 25000, 35000]
# })
# ```
#
# </aside>

# %%
df1 = pd.DataFrame({'고객ID': [1, 2, 3],'도시': ['서울', '부산', '대전'],'구매액': [10000, 20000, 30000]})
df2 = pd.DataFrame({'고객ID': [1, 2, 3],'도시': ['서울', '부산', '광주'],'구매액': [15000, 25000, 35000]})

#df1 과 df2 에서는 고객id만 동일하고 도시와 구매액이 달라진 상황.
#고객ID를 조인키로 잡고 (기준이 되고) 합치기
print(pd.merge(df1, df2, on='고객ID', suffixes=('_기존', '_신규')))
# Out:
#    고객ID 도시_기존  구매액_기존 도시_신규  구매액_신규
# 0     1    서울   10000    서울   15000
# 1     2    부산   20000    부산   25000
# 2     3    대전   30000    광주   35000

# %% [markdown]
# # 결측치 처리 교재

# %% [markdown]
# # 결측치 처리 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 결측치를 탐지하고, 열별 결측치 개수를 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# import numpy as np
#
# data = {'이름': ['홍길동', '김철수', np.nan, '이영희'],
#         '나이': [25, np.nan, 30, 28],
#         '성별': ['남', '남', '여', np.nan]}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
import numpy as np

data = {'이름': ['홍길동', '김철수', np.nan, '이영희'],
        '나이': [25, np.nan, 30, 28],
        '성별': ['남', '남', '여', np.nan]}

df = pd.DataFrame(data)

print(df, '\n\n')
print(df.isnull().sum())
# Out:
#     이름    나이   성별
# 0  홍길동  25.0    남
# 1  김철수   NaN    남
# 2  NaN  30.0    여
# 3  이영희  28.0  NaN
#
#
# 이름    1
# 나이    1
# 성별    1
# dtype: int64

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 결측치가 포함된 행을 삭제하고, 새로운 데이터프레임을 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# import numpy as np
#
# data = {'이름': ['홍길동', '김철수', np.nan, '이영희'],
#         '나이': [25, np.nan, 30, 28],
#         '성별': ['남', '남', '여', np.nan]}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
print(df.dropna(), '\n\n')

#결측치가 제거되었는지 확인
#결과를 확인해보니 기존 데이터프레임은 그대로.
print(df)
# Out:
#     이름    나이 성별
# 0  홍길동  25.0  남
#
#
#     이름    나이   성별
# 0  홍길동  25.0    남
# 1  김철수   NaN    남
# 2  NaN  30.0    여
# 3  이영희  28.0  NaN

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 결측치가 포함된 '나이' 열을 평균값으로 대체하고, 새로운 데이터프레임을 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# import numpy as np
#
# data = {'이름': ['홍길동', '김철수', np.nan, '이영희'],
#         '나이': [25, np.nan, 30, 28],
#         '성별': ['남', '남', '여', np.nan]}
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
df_age_mean = df.copy()   #<-- 원본 훼손 방지로 복사
df_age_mean['나이'] = df_age_mean['나이'].fillna(df_age_mean['나이'].mean())
print(df_age_mean, '\n\n')

#나이 - 데이터타입 변경
df_age_mean['나이'] = df_age_mean['나이'].astype(int)
print(df_age_mean)
# Out:
#     이름         나이   성별
# 0  홍길동  25.000000    남
# 1  김철수  27.666667    남
# 2  NaN  30.000000    여
# 3  이영희  28.000000  NaN
#
#
#     이름  나이   성별
# 0  홍길동  25    남
# 1  김철수  27    남
# 2  NaN  30    여
# 3  이영희  28  NaN

# %% [markdown]
# # 피벗 교재

# %% [markdown]
# # 피벗 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임을 `pivot()` 함수를 사용하여 날짜(`날짜`)를 행 인덱스로, 제품(`제품`)을 열로, 판매량(`판매량`)을 값으로 설정하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '날짜': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
#     '제품': ['A', 'B', 'A', 'B'],
#     '판매량': [100, 200, 150, 250]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '날짜': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
    '제품': ['A', 'B', 'A', 'B'],
    '판매량': [100, 200, 150, 250]
}
df = pd.DataFrame(data)

print(df.pivot(index='날짜', columns='제품', values='판매량'))
# Out:
# 제품            A    B
# 날짜
# 2024-01-01  100  200
# 2024-01-02  150  250

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 `pivot_table()`을 사용하여 주어진 데이터프레임에서 카테고리(`카테고리`)를 행 인덱스로, 제품(`제품`)을 열로 설정하고, 판매량(`판매량`)의 합계를 출력하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '카테고리': ['전자', '가전', '전자', '가전'],
#     '제품': ['A', 'B', 'A', 'B'],
#     '판매량': [100, 200, 150, 250]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '카테고리': ['전자', '가전', '전자', '가전'],
    '제품': ['A', 'B', 'A', 'B'],
    '판매량': [100, 200, 150, 250]
}

df = pd.DataFrame(data)

#pivot()을 하면 중복된 데이터가 있는 경우 오류가 발생 --> pivot_table 사용!
print(df.pivot_table(index='카테고리', columns='제품', values='판매량'))
# Out:
# 제품        A      B
# 카테고리
# 가전      NaN  225.0
# 전자    125.0    NaN

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 여러 값을 동시에 피벗하여, `pivot()`을 사용해 날짜(`날짜`)를 행으로, 제품(`제품`)을 열로 설정하고, 판매량(`판매량`)과 이익(`이익`)을 동시에 피벗하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '날짜': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
#     '제품': ['A', 'B', 'A', 'B'],
#     '판매량': [100, 200, 150, 250],
#     '이익': [20, 50, 30, 60]
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '날짜': ['2024-01-01', '2024-01-01', '2024-01-02', '2024-01-02'],
    '제품': ['A', 'B', 'A', 'B'],
    '판매량': [100, 200, 150, 250],
    '이익': [20, 50, 30, 60]
}

df = pd.DataFrame(data)

print(df.pivot_table(index='날짜', columns='제품', values=['판매량', '이익']))
# Out:
#               이익          판매량
# 제품             A     B      A      B
# 날짜
# 2024-01-01  20.0  50.0  100.0  200.0
# 2024-01-02  30.0  60.0  150.0  250.0

# %% [markdown]
# # 중복제거 교재

# %% [markdown]
# # 중복제거 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 주어진 데이터프레임에서 기본적으로 중복된 행을 제거하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '이름': ['김철수', '이영희', '김철수', '박민수'],
#     '나이': [25, 30, 25, 40],
#     '성별': ['남', '여', '남', '남']
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '이름': ['김철수', '이영희', '김철수', '박민수'],
    '나이': [25, 30, 25, 40],
    '성별': ['남', '여', '남', '남']
}
df = pd.DataFrame(data)

#중복 제거 -- 모든 열
print(df.drop_duplicates())
# Out:
#     이름  나이 성별
# 0  김철수  25  남
# 1  이영희  30  여
# 3  박민수  40  남

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 다음 데이터프레임에서 특정 열을 기준으로 중복을 제거한 후, 중복 여부를 확인하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '제품': ['노트북', '태블릿', '노트북', '스마트폰'],
#     '가격': [1500000, 800000, 1500000, 1000000],
#     '카테고리': ['전자기기', '전자기기', '전자기기', '전자기기']
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '제품': ['노트북', '태블릿', '노트북', '스마트폰'],
    '가격': [1500000, 800000, 1500000, 1000000],
    '카테고리': ['전자기기', '전자기기', '전자기기', '전자기기']
}
df = pd.DataFrame(data)

#중복 제거 -- 특정 열 기준
#print(df.drop_duplicates(subset=['제품']))

#------------------
#중복 여부 확인할 열 생성
df['중복여부'] = df.duplicated()

#새로운 데이터프레임 생성해서 중복을 제거
new_df = df.drop_duplicates(subset=['제품'])

#최종 출력
print(f"원본 데이터 : \n {df}\n\n")
print(f"중복 제거한 데이터 : \n {new_df}")
# Out:
# 원본 데이터 :
#       제품       가격  카테고리   중복여부
# 0   노트북  1500000  전자기기  False
# 1   태블릿   800000  전자기기  False
# 2   노트북  1500000  전자기기   True
# 3  스마트폰  1000000  전자기기  False
#
#
# 중복 제거한 데이터 :
#       제품       가격  카테고리   중복여부
# 0   노트북  1500000  전자기기  False
# 1   태블릿   800000  전자기기  False
# 3  스마트폰  1000000  전자기기  False

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 다음 데이터프레임에서 중복된 모든 행을 삭제한 후, 남은 데이터를 저장하고 다시 불러오는 코드를 작성하세요.
#
# ```python
# import pandas as pd
#
# data = {
#     '학생': ['김민수', '박지현', '김민수', '이정훈'],
#     '성적': [90, 85, 90, 88],
#     '학교': ['A고', 'B고', 'A고', 'C고']
# }
#
# df = pd.DataFrame(data)
# ```
#
# </aside>

# %%
data = {
    '학생': ['김민수', '박지현', '김민수', '이정훈'],
    '성적': [90, 85, 90, 88],
    '학교': ['A고', 'B고', 'A고', 'C고']
}

df = pd.DataFrame(data)

#중복 제거
new_df = df.drop_duplicates()
print("중복 제거한 데이터: ")
print(new_df,' \n\n')

#csv로 저장
new_df.to_csv('df_csv.csv', index=False)

#다시 읽기
df_loaded = pd.read_csv('df_csv.csv')
print("데이터 저장 후 다시 읽기: ")
print(df_loaded)
# Out:
# 중복 제거한 데이터:
#     학생  성적  학교
# 0  김민수  90  A고
# 1  박지현  85  B고
# 3  이정훈  88  C고
#
#
# 데이터 저장 후 다시 읽기:
#     학생  성적  학교
# 0  김민수  90  A고
# 1  박지현  85  B고
# 2  이정훈  88  C고

# %% [markdown]
# # 문자열 처리 교재

# %% [markdown]
# # 문자열 처리 미니퀘스트

# %% [markdown]
# ### 1번 퀘스트
#
# <aside>
# 👉 Pandas의 `.str` 접근자를 사용하여 아래 시리즈의 모든 문자열을 소문자로 변환하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# data = pd.Series(["HELLO", "WORLD", "PYTHON", "PANDAS"])
# ```
#
# </aside>

# %%
data = pd.Series(["HELLO", "WORLD", "PYTHON", "PANDAS"])

print(data.str.lower())
# Out:
# 0     hello
# 1     world
# 2    python
# 3    pandas
# dtype: object

# %% [markdown]
# ### 2번 퀘스트
#
# <aside>
# 👉 다음 데이터프레임에서 '이름' 컬럼의 문자열 앞뒤 공백을 제거하고, 특정 문자열 "Doe"가 포함된 행을 필터링하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# df = pd.DataFrame({"이름": [" John Doe ", "Alice ", " Bob", "Charlie Doe "]})
# ```
#
# </aside>

# %%
df = pd.DataFrame({"이름": [" John Doe ", "Alice ", " Bob", "Charlie Doe "]})

#기존 데이터프레임
print(f'기존 데이터프레임:\n{df}\n\n')

#이름 공백 제거
df["이름"] = df["이름"].str.strip()
print(f'이름공백제거 데이터프레임:\n{df}\n\n')

#특정 문자열 필터링 출력
print('특정 문자열 필터링:\n', df[df['이름'].str.contains('Doe')])
# Out:
# 기존 데이터프레임:
#              이름
# 0     John Doe
# 1        Alice
# 2           Bob
# 3  Charlie Doe
#
#
# 이름공백제거 데이터프레임:
#             이름
# 0     John Doe
# 1        Alice
# 2          Bob
# 3  Charlie Doe
#
#
# 특정 문자열 필터링:
#              이름
# 0     John Doe
# 3  Charlie Doe

# %% [markdown]
# ### 3번 퀘스트
#
# <aside>
# 👉 아래 데이터프레임에서 '설명' 컬럼의 문자열을 공백을 기준으로 나누고, 각 단어의 첫 글자만 추출하여 새로운 컬럼 '약어'를 생성하는 코드를 작성하세요.
#
# ```python
# import pandas as pd
# df = pd.DataFrame({"설명": ["빅데이터 분석", "데이터 과학", "머신 러닝", "딥 러닝"]})
# ```
#
# </aside>

# %%
df = pd.DataFrame({"설명": ["빅데이터 분석", "데이터 과학", "머신 러닝", "딥 러닝"]})
print(f'기존 데이터프레임:\n{df}\n\n')

#특정 문자열을 공백을 기준으로 나누기
df["설명"] = df["설명"].str.split(' ')
print(f'나눈 데이터프레임:\n{df}\n\n')

#첫 단어만 추출
df['단어1'] = df['설명'].str[0]
df['단어2'] = df['설명'].str[1]
print(f'첫 단어 데이터프레임:\n{df}\n\n')

#첫 단어 중 첫 글자만 추출
df['약어1'] = df['단어1'].str[0]
df['약어2'] = df['단어2'].str[0]
print(f'약어 데이터프레임:\n{df}\n\n')
# Out:
# 기존 데이터프레임:
#         설명
# 0  빅데이터 분석
# 1   데이터 과학
# 2    머신 러닝
# 3     딥 러닝
#
#
# 나눈 데이터프레임:
#            설명
# 0  [빅데이터, 분석]
# 1   [데이터, 과학]
# 2    [머신, 러닝]
# 3     [딥, 러닝]
#
#
# 첫 단어 데이터프레임:
#            설명   단어1 단어2
# 0  [빅데이터, 분석]  빅데이터  분석
# 1   [데이터, 과학]   데이터  과학
# 2    [머신, 러닝]    머신  러닝
# 3     [딥, 러닝]     딥  러닝
#
#
# 약어 데이터프레임:
#            설명   단어1 단어2 약어1 약어2
# 0  [빅데이터, 분석]  빅데이터  분석   빅   분
# 1   [데이터, 과학]   데이터  과학   데   과
# 2    [머신, 러닝]    머신  러닝   머   러
# 3     [딥, 러닝]     딥  러닝   딥   러

# %%
# 🤖제미나이 답변

# ===== 여기까지는 동일하게 진행했을 시 ======
df = pd.DataFrame({"설명": ["빅데이터 분석", "데이터 과학", "머신 러닝", "딥 러닝"]})
print(f'기존 데이터프레임:\n{df}\n\n')

#특정 문자열을 공백을 기준으로 나누기
df["설명"] = df["설명"].str.split(' ')
print(f'나눈 데이터프레임:\n{df}\n\n')
# ====================================

# 🤖 현재 df['설명']은 ['빅데이터', '분석']과 같이 리스트 형태입니다.
# 🤖 각 리스트 요소의 첫 글자([0])만 가져와서 합칩니다.
df['약어'] = df['설명'].apply(lambda x: "".join([word[0] for word in x]))
print(f'약어 컬럼이 추가된 데이터프레임:\n{df}')
# Out:
# 기존 데이터프레임:
#         설명
# 0  빅데이터 분석
# 1   데이터 과학
# 2    머신 러닝
# 3     딥 러닝
#
#
# 나눈 데이터프레임:
#            설명
# 0  [빅데이터, 분석]
# 1   [데이터, 과학]
# 2    [머신, 러닝]
# 3     [딥, 러닝]
#
#
# 약어 컬럼이 추가된 데이터프레임:
#            설명  약어
# 0  [빅데이터, 분석]  빅분
# 1   [데이터, 과학]  데과
# 2    [머신, 러닝]  머러
# 3     [딥, 러닝]  딥러
